# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamt2897/DL_BB_YOLO/blob/main/DL_BB_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision torchaudio --upgrade
# !pip install matplotlib opencv-python albumentations onnx onnxruntime
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Collecting torch
#   Downloading torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.20.1+cu124)
# Collecting torchvision
#   Downloading torchvision-0.21.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Collecting torchaudio
#   Downloading torchaudio-2.6.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch)
#   Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.2.0 (from torch)
#   Downloading triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl (766.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 26.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 24.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 19.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.4 MB/s eta 0:00:00
# Downloading triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 5.2 MB/s eta 0:00:00
# Downloading torchvision-0.21.0-cp311-cp311-manylinux1_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 89.7 MB/s eta 0:00:00
# Downloading torchaudio-2.6.0-cp311-cp311-manylinux1_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 75.8 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-cusparselt-cu12, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu124
#     Uninstalling torch-2.5.1+cu124:
#       Successfully uninstalled torch-2.5.1+cu124
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu124
#     Uninstalling torchvision-0.20.1+cu124:
#       Successfully uninstalled torchvision-0.20.1+cu124
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.5.1+cu124
#     Uninstalling torchaudio-2.5.1+cu124:
#       Successfully uninstalled torchaudio-2.5.1+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.18 requires torch<2.6,>=1.10, but you have torch 2.6.0 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nvjitlink-cu12-12.4.127 torch-2.6.0 torchaudio-2.6.0 torchvision-0.21.0 triton-3.2.0
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.11/dist-packages (2.0.4)
# Collecting onnx
#   Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting onnxruntime
#   Downloading onnxruntime-1.20.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from albumentations) (1.13.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from albumentations) (2.10.6)
# Requirement already satisfied: albucore==0.0.23 in /usr/local/lib/python3.11/dist-packages (from albumentations) (0.0.23)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albumentations) (4.11.0.86)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.23->albumentations) (3.11.3)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.23->albumentations) (6.2.1)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from onnx) (4.25.6)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (25.2.10)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (1.13.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime) (1.3.0)
# Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 95.6 MB/s eta 0:00:00
# Downloading onnxruntime-1.20.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 97.1 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.3 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.3 MB/s eta 0:00:00
# Installing collected packages: onnx, humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnx-1.17.0 onnxruntime-1.20.1

# %%
# !gdown "https://drive.google.com/uc?id=11s-GLb6LZ0SCAVW6aikqImuuQEEbT_Fb" -O dl_challenge.tar.xz
# !tar -xvf dl_challenge.tar.xz
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=11s-GLb6LZ0SCAVW6aikqImuuQEEbT_Fb
# From (redirected): https://drive.google.com/uc?id=11s-GLb6LZ0SCAVW6aikqImuuQEEbT_Fb&confirm=t&uuid=64f80f10-c100-42a3-b5f5-9168cb092763
# To: /content/dl_challenge.tar.xz
# 100% 2.44G/2.44G [00:24<00:00, 101MB/s]
# dl_challenge/
# dl_challenge/889a9fb3-9915-11ee-9103-bbb8eae05561/
# dl_challenge/889a9fb3-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/889a9fb3-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/889a9fb3-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/889a9fb3-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/911224fa-9915-11ee-9103-bbb8eae05561/
# dl_challenge/911224fa-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/911224fa-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/911224fa-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/911224fa-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9f50f3c2-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9f50f3c2-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9f50f3c2-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9f50f3c2-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9f50f3c2-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9950f10e-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9950f10e-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9950f10e-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9950f10e-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9950f10e-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/936fee3b-9915-11ee-9103-bbb8eae05561/
# dl_challenge/936fee3b-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/936fee3b-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/936fee3b-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/936fee3b-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/889a9fb6-9915-11ee-9103-bbb8eae05561/
# dl_challenge/889a9fb6-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/889a9fb6-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/889a9fb6-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/889a9fb6-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/a0818ba9-9915-11ee-9103-bbb8eae05561/
# dl_challenge/a0818ba9-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/a0818ba9-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/a0818ba9-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/a0818ba9-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9f50f3c1-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9f50f3c1-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9f50f3c1-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9f50f3c1-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9f50f3c1-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/94855efa-9915-11ee-9103-bbb8eae05561/
# dl_challenge/94855efa-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/94855efa-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/94855efa-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/94855efa-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/a1c1d8c1-9915-11ee-9103-bbb8eae05561/
# dl_challenge/a1c1d8c1-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/a1c1d8c1-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/a1c1d8c1-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/a1c1d8c1-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/983022ad-9915-11ee-9103-bbb8eae05561/
# dl_challenge/983022ad-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/983022ad-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/983022ad-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/983022ad-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/a0818baa-9915-11ee-9103-bbb8eae05561/
# dl_challenge/a0818baa-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/a0818baa-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/a0818baa-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/a0818baa-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/a1c1d8c5-9915-11ee-9103-bbb8eae05561/
# dl_challenge/a1c1d8c5-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/a1c1d8c5-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/a1c1d8c5-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/a1c1d8c5-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/922c1c96-9915-11ee-9103-bbb8eae05561/
# dl_challenge/922c1c96-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/922c1c96-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/922c1c96-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/922c1c96-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/983022ac-9915-11ee-9103-bbb8eae05561/
# dl_challenge/983022ac-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/983022ac-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/983022ac-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/983022ac-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9f50f3bf-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9f50f3bf-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9f50f3bf-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9f50f3bf-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9f50f3bf-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9bccdb7c-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9bccdb7c-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9bccdb7c-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9bccdb7c-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9bccdb7c-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9ce28680-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9ce28680-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9ce28680-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9ce28680-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9ce28680-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8d6c823c-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8d6c823c-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8d6c823c-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8d6c823c-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8d6c823c-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8658b66d-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8658b66d-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8658b66d-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8658b66d-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8658b66d-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/89ceef15-9915-11ee-9103-bbb8eae05561/
# dl_challenge/89ceef15-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/89ceef15-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/89ceef15-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/89ceef15-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9e1ed84a-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9e1ed84a-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9e1ed84a-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9e1ed84a-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9e1ed84a-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/a0818ba5-9915-11ee-9103-bbb8eae05561/
# dl_challenge/a0818ba5-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/a0818ba5-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/a0818ba5-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/a0818ba5-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8eaf3ee6-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8eaf3ee6-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8eaf3ee6-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8eaf3ee6-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8eaf3ee6-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8d6c823e-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8d6c823e-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8d6c823e-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8d6c823e-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8d6c823e-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/95c679d2-9915-11ee-9103-bbb8eae05561/
# dl_challenge/95c679d2-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/95c679d2-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/95c679d2-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/95c679d2-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/a1c1d8c3-9915-11ee-9103-bbb8eae05561/
# dl_challenge/a1c1d8c3-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/a1c1d8c3-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/a1c1d8c3-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/a1c1d8c3-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/95c679d1-9915-11ee-9103-bbb8eae05561/
# dl_challenge/95c679d1-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/95c679d1-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/95c679d1-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/95c679d1-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9ce2867e-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9ce2867e-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9ce2867e-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9ce2867e-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9ce2867e-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/983022a9-9915-11ee-9103-bbb8eae05561/
# dl_challenge/983022a9-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/983022a9-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/983022a9-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/983022a9-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8c394191-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8c394191-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8c394191-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8c394191-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8c394191-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8fc581d7-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8fc581d7-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8fc581d7-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8fc581d7-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8fc581d7-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/922c1c94-9915-11ee-9103-bbb8eae05561/
# dl_challenge/922c1c94-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/922c1c94-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/922c1c94-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/922c1c94-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8fc581d3-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8fc581d3-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8fc581d3-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8fc581d3-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8fc581d3-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/878250cb-9915-11ee-9103-bbb8eae05561/
# dl_challenge/878250cb-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/878250cb-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/878250cb-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/878250cb-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9a7caa9c-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9a7caa9c-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9a7caa9c-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9a7caa9c-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9a7caa9c-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/89ceef1a-9915-11ee-9103-bbb8eae05561/
# dl_challenge/89ceef1a-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/89ceef1a-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/89ceef1a-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/89ceef1a-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9ce28682-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9ce28682-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9ce28682-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9ce28682-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9ce28682-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9bccdb7d-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9bccdb7d-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9bccdb7d-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9bccdb7d-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9bccdb7d-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8c394192-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8c394192-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8c394192-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8c394192-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8c394192-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9f50f3c4-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9f50f3c4-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9f50f3c4-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9f50f3c4-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9f50f3c4-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8c394190-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8c394190-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8c394190-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8c394190-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8c394190-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/859074c5-9915-11ee-9103-bbb8eae05561/
# dl_challenge/859074c5-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/859074c5-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/859074c5-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/859074c5-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/878250d1-9915-11ee-9103-bbb8eae05561/
# dl_challenge/878250d1-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/878250d1-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/878250d1-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/878250d1-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8c39418e-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8c39418e-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8c39418e-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8c39418e-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8c39418e-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9ce28685-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9ce28685-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9ce28685-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9ce28685-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9ce28685-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8658b670-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8658b670-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8658b670-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8658b670-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8658b670-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9f50f3c6-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9f50f3c6-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9f50f3c6-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9f50f3c6-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9f50f3c6-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/889a9fb5-9915-11ee-9103-bbb8eae05561/
# dl_challenge/889a9fb5-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/889a9fb5-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/889a9fb5-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/889a9fb5-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/a2d44073-9915-11ee-9103-bbb8eae05561/
# dl_challenge/a2d44073-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/a2d44073-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/a2d44073-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/a2d44073-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/96e66c71-9915-11ee-9103-bbb8eae05561/
# dl_challenge/96e66c71-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/96e66c71-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/96e66c71-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/96e66c71-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/859074c2-9915-11ee-9103-bbb8eae05561/
# dl_challenge/859074c2-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/859074c2-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/859074c2-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/859074c2-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/911224fd-9915-11ee-9103-bbb8eae05561/
# dl_challenge/911224fd-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/911224fd-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/911224fd-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/911224fd-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/936fee38-9915-11ee-9103-bbb8eae05561/
# dl_challenge/936fee38-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/936fee38-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/936fee38-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/936fee38-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9ce28683-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9ce28683-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9ce28683-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9ce28683-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9ce28683-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8fc581d6-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8fc581d6-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8fc581d6-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8fc581d6-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8fc581d6-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8658b66f-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8658b66f-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8658b66f-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8658b66f-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8658b66f-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8c39418d-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8c39418d-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8c39418d-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8c39418d-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8c39418d-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9bccdb7f-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9bccdb7f-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9bccdb7f-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9bccdb7f-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9bccdb7f-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/89ceef16-9915-11ee-9103-bbb8eae05561/
# dl_challenge/89ceef16-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/89ceef16-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/89ceef16-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/89ceef16-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/859074c4-9915-11ee-9103-bbb8eae05561/
# dl_challenge/859074c4-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/859074c4-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/859074c4-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/859074c4-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8b061a8a-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8b061a8a-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8b061a8a-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8b061a8a-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8b061a8a-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/936fee39-9915-11ee-9103-bbb8eae05561/
# dl_challenge/936fee39-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/936fee39-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/936fee39-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/936fee39-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9e1ed849-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9e1ed849-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9e1ed849-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9e1ed849-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9e1ed849-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8658b66e-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8658b66e-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8658b66e-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8658b66e-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8658b66e-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/936fee3e-9915-11ee-9103-bbb8eae05561/
# dl_challenge/936fee3e-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/936fee3e-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/936fee3e-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/936fee3e-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9e1ed846-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9e1ed846-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9e1ed846-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9e1ed846-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9e1ed846-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9950f10f-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9950f10f-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9950f10f-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9950f10f-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9950f10f-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/96e66c6d-9915-11ee-9103-bbb8eae05561/
# dl_challenge/96e66c6d-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/96e66c6d-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/96e66c6d-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/96e66c6d-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9a7caa9b-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9a7caa9b-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9a7caa9b-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9a7caa9b-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9a7caa9b-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/878250cd-9915-11ee-9103-bbb8eae05561/
# dl_challenge/878250cd-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/878250cd-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/878250cd-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/878250cd-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/96e66c69-9915-11ee-9103-bbb8eae05561/
# dl_challenge/96e66c69-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/96e66c69-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/96e66c69-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/96e66c69-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/859074c6-9915-11ee-9103-bbb8eae05561/
# dl_challenge/859074c6-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/859074c6-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/859074c6-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/859074c6-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/96e66c6f-9915-11ee-9103-bbb8eae05561/
# dl_challenge/96e66c6f-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/96e66c6f-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/96e66c6f-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/96e66c6f-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9ce28686-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9ce28686-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9ce28686-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9ce28686-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9ce28686-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8b061a90-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8b061a90-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8b061a90-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8b061a90-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8b061a90-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9a7caa9a-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9a7caa9a-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9a7caa9a-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9a7caa9a-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9a7caa9a-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9f50f3be-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9f50f3be-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9f50f3be-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9f50f3be-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9f50f3be-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9a7caaa1-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9a7caaa1-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9a7caaa1-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9a7caaa1-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9a7caaa1-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9950f109-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9950f109-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9950f109-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9950f109-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9950f109-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/922c1c91-9915-11ee-9103-bbb8eae05561/
# dl_challenge/922c1c91-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/922c1c91-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/922c1c91-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/922c1c91-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9e1ed848-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9e1ed848-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9e1ed848-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9e1ed848-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9e1ed848-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/878250cc-9915-11ee-9103-bbb8eae05561/
# dl_challenge/878250cc-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/878250cc-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/878250cc-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/878250cc-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/95c679ce-9915-11ee-9103-bbb8eae05561/
# dl_challenge/95c679ce-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/95c679ce-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/95c679ce-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/95c679ce-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8eaf3ee9-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8eaf3ee9-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8eaf3ee9-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8eaf3ee9-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8eaf3ee9-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9a7caaa0-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9a7caaa0-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9a7caaa0-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9a7caaa0-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9a7caaa0-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9e1ed845-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9e1ed845-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9e1ed845-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9e1ed845-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9e1ed845-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8b061a8f-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8b061a8f-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8b061a8f-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8b061a8f-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8b061a8f-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/889a9fb9-9915-11ee-9103-bbb8eae05561/
# dl_challenge/889a9fb9-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/889a9fb9-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/889a9fb9-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/889a9fb9-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/a2d44072-9915-11ee-9103-bbb8eae05561/
# dl_challenge/a2d44072-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/a2d44072-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/a2d44072-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/a2d44072-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/89ceef18-9915-11ee-9103-bbb8eae05561/
# dl_challenge/89ceef18-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/89ceef18-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/89ceef18-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/89ceef18-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9ce28684-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9ce28684-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9ce28684-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9ce28684-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9ce28684-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9a7caa9f-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9a7caa9f-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9a7caa9f-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9a7caa9f-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9a7caa9f-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8eaf3ee8-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8eaf3ee8-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8eaf3ee8-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8eaf3ee8-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8eaf3ee8-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9f50f3c3-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9f50f3c3-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9f50f3c3-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9f50f3c3-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9f50f3c3-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/a2d44075-9915-11ee-9103-bbb8eae05561/
# dl_challenge/a2d44075-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/a2d44075-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/a2d44075-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/a2d44075-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/911224fc-9915-11ee-9103-bbb8eae05561/
# dl_challenge/911224fc-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/911224fc-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/911224fc-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/911224fc-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9950f108-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9950f108-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9950f108-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9950f108-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9950f108-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8d6c8241-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8d6c8241-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8d6c8241-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8d6c8241-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8d6c8241-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/94855ef8-9915-11ee-9103-bbb8eae05561/
# dl_challenge/94855ef8-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/94855ef8-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/94855ef8-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/94855ef8-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/94855ef6-9915-11ee-9103-bbb8eae05561/
# dl_challenge/94855ef6-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/94855ef6-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/94855ef6-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/94855ef6-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/922c1c93-9915-11ee-9103-bbb8eae05561/
# dl_challenge/922c1c93-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/922c1c93-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/922c1c93-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/922c1c93-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/878250ca-9915-11ee-9103-bbb8eae05561/
# dl_challenge/878250ca-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/878250ca-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/878250ca-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/878250ca-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9f50f3c5-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9f50f3c5-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9f50f3c5-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9f50f3c5-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9f50f3c5-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/96e66c6b-9915-11ee-9103-bbb8eae05561/
# dl_challenge/96e66c6b-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/96e66c6b-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/96e66c6b-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/96e66c6b-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8fc581d4-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8fc581d4-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8fc581d4-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8fc581d4-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8fc581d4-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9bccdb80-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9bccdb80-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9bccdb80-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9bccdb80-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9bccdb80-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/889a9fb8-9915-11ee-9103-bbb8eae05561/
# dl_challenge/889a9fb8-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/889a9fb8-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/889a9fb8-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/889a9fb8-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/859074c3-9915-11ee-9103-bbb8eae05561/
# dl_challenge/859074c3-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/859074c3-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/859074c3-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/859074c3-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/911224ff-9915-11ee-9103-bbb8eae05561/
# dl_challenge/911224ff-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/911224ff-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/911224ff-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/911224ff-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9ce28681-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9ce28681-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9ce28681-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9ce28681-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9ce28681-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/889a9fb7-9915-11ee-9103-bbb8eae05561/
# dl_challenge/889a9fb7-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/889a9fb7-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/889a9fb7-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/889a9fb7-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8b061a88-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8b061a88-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8b061a88-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8b061a88-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8b061a88-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8d6c823a-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8d6c823a-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8d6c823a-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8d6c823a-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8d6c823a-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9bccdb7e-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9bccdb7e-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9bccdb7e-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9bccdb7e-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9bccdb7e-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/936fee3d-9915-11ee-9103-bbb8eae05561/
# dl_challenge/936fee3d-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/936fee3d-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/936fee3d-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/936fee3d-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8b061a8c-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8b061a8c-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8b061a8c-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8b061a8c-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8b061a8c-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/983022af-9915-11ee-9103-bbb8eae05561/
# dl_challenge/983022af-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/983022af-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/983022af-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/983022af-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/89ceef17-9915-11ee-9103-bbb8eae05561/
# dl_challenge/89ceef17-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/89ceef17-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/89ceef17-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/89ceef17-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/936fee3a-9915-11ee-9103-bbb8eae05561/
# dl_challenge/936fee3a-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/936fee3a-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/936fee3a-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/936fee3a-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/a0818ba6-9915-11ee-9103-bbb8eae05561/
# dl_challenge/a0818ba6-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/a0818ba6-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/a0818ba6-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/a0818ba6-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9ce28687-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9ce28687-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9ce28687-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9ce28687-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9ce28687-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8b061a8d-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8b061a8d-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8b061a8d-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8b061a8d-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8b061a8d-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/94855ef7-9915-11ee-9103-bbb8eae05561/
# dl_challenge/94855ef7-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/94855ef7-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/94855ef7-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/94855ef7-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/95c679cf-9915-11ee-9103-bbb8eae05561/
# dl_challenge/95c679cf-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/95c679cf-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/95c679cf-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/95c679cf-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/95c679cc-9915-11ee-9103-bbb8eae05561/
# dl_challenge/95c679cc-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/95c679cc-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/95c679cc-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/95c679cc-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/89ceef19-9915-11ee-9103-bbb8eae05561/
# dl_challenge/89ceef19-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/89ceef19-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/89ceef19-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/89ceef19-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/878250ce-9915-11ee-9103-bbb8eae05561/
# dl_challenge/878250ce-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/878250ce-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/878250ce-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/878250ce-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/a1c1d8c0-9915-11ee-9103-bbb8eae05561/
# dl_challenge/a1c1d8c0-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/a1c1d8c0-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/a1c1d8c0-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/a1c1d8c0-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9e1ed84b-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9e1ed84b-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9e1ed84b-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9e1ed84b-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9e1ed84b-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/878250d0-9915-11ee-9103-bbb8eae05561/
# dl_challenge/878250d0-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/878250d0-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/878250d0-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/878250d0-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/911224fe-9915-11ee-9103-bbb8eae05561/
# dl_challenge/911224fe-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/911224fe-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/911224fe-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/911224fe-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8eaf3ee4-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8eaf3ee4-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8eaf3ee4-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8eaf3ee4-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8eaf3ee4-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/922c1c92-9915-11ee-9103-bbb8eae05561/
# dl_challenge/922c1c92-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/922c1c92-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/922c1c92-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/922c1c92-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8fc581d5-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8fc581d5-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8fc581d5-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8fc581d5-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8fc581d5-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9a7caa9d-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9a7caa9d-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9a7caa9d-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9a7caa9d-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9a7caa9d-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/a1c1d8c4-9915-11ee-9103-bbb8eae05561/
# dl_challenge/a1c1d8c4-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/a1c1d8c4-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/a1c1d8c4-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/a1c1d8c4-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/878250cf-9915-11ee-9103-bbb8eae05561/
# dl_challenge/878250cf-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/878250cf-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/878250cf-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/878250cf-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9f50f3c0-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9f50f3c0-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9f50f3c0-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9f50f3c0-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9f50f3c0-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/889a9fb2-9915-11ee-9103-bbb8eae05561/
# dl_challenge/889a9fb2-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/889a9fb2-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/889a9fb2-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/889a9fb2-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/922c1c95-9915-11ee-9103-bbb8eae05561/
# dl_challenge/922c1c95-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/922c1c95-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/922c1c95-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/922c1c95-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/96e66c6a-9915-11ee-9103-bbb8eae05561/
# dl_challenge/96e66c6a-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/96e66c6a-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/96e66c6a-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/96e66c6a-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/922c1c90-9915-11ee-9103-bbb8eae05561/
# dl_challenge/922c1c90-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/922c1c90-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/922c1c90-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/922c1c90-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/983022aa-9915-11ee-9103-bbb8eae05561/
# dl_challenge/983022aa-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/983022aa-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/983022aa-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/983022aa-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9e1ed847-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9e1ed847-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9e1ed847-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9e1ed847-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9e1ed847-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/94855ef4-9915-11ee-9103-bbb8eae05561/
# dl_challenge/94855ef4-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/94855ef4-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/94855ef4-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/94855ef4-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/a0818ba8-9915-11ee-9103-bbb8eae05561/
# dl_challenge/a0818ba8-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/a0818ba8-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/a0818ba8-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/a0818ba8-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/96e66c6e-9915-11ee-9103-bbb8eae05561/
# dl_challenge/96e66c6e-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/96e66c6e-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/96e66c6e-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/96e66c6e-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8b061a8b-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8b061a8b-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8b061a8b-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8b061a8b-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8b061a8b-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/96e66c68-9915-11ee-9103-bbb8eae05561/
# dl_challenge/96e66c68-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/96e66c68-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/96e66c68-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/96e66c68-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/96e66c70-9915-11ee-9103-bbb8eae05561/
# dl_challenge/96e66c70-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/96e66c70-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/96e66c70-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/96e66c70-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9e1ed844-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9e1ed844-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9e1ed844-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9e1ed844-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9e1ed844-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9950f10c-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9950f10c-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9950f10c-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9950f10c-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9950f10c-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9950f10b-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9950f10b-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9950f10b-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9950f10b-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9950f10b-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/859074c7-9915-11ee-9103-bbb8eae05561/
# dl_challenge/859074c7-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/859074c7-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/859074c7-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/859074c7-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/94855ef2-9915-11ee-9103-bbb8eae05561/
# dl_challenge/94855ef2-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/94855ef2-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/94855ef2-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/94855ef2-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8fc581d1-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8fc581d1-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8fc581d1-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8fc581d1-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8fc581d1-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/911224f9-9915-11ee-9103-bbb8eae05561/
# dl_challenge/911224f9-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/911224f9-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/911224f9-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/911224f9-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/89ceef14-9915-11ee-9103-bbb8eae05561/
# dl_challenge/89ceef14-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/89ceef14-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/89ceef14-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/89ceef14-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/a1c1d8c6-9915-11ee-9103-bbb8eae05561/
# dl_challenge/a1c1d8c6-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/a1c1d8c6-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/a1c1d8c6-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/a1c1d8c6-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8eaf3eea-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8eaf3eea-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8eaf3eea-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8eaf3eea-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8eaf3eea-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/96e66c6c-9915-11ee-9103-bbb8eae05561/
# dl_challenge/96e66c6c-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/96e66c6c-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/96e66c6c-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/96e66c6c-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/94855ef5-9915-11ee-9103-bbb8eae05561/
# dl_challenge/94855ef5-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/94855ef5-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/94855ef5-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/94855ef5-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/922c1c97-9915-11ee-9103-bbb8eae05561/
# dl_challenge/922c1c97-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/922c1c97-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/922c1c97-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/922c1c97-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/983022ab-9915-11ee-9103-bbb8eae05561/
# dl_challenge/983022ab-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/983022ab-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/983022ab-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/983022ab-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/95c679d0-9915-11ee-9103-bbb8eae05561/
# dl_challenge/95c679d0-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/95c679d0-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/95c679d0-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/95c679d0-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8d6c823d-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8d6c823d-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8d6c823d-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8d6c823d-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8d6c823d-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/a0818ba4-9915-11ee-9103-bbb8eae05561/
# dl_challenge/a0818ba4-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/a0818ba4-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/a0818ba4-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/a0818ba4-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8fc581d2-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8fc581d2-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8fc581d2-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8fc581d2-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8fc581d2-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/936fee3f-9915-11ee-9103-bbb8eae05561/
# dl_challenge/936fee3f-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/936fee3f-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/936fee3f-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/936fee3f-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9e1ed84c-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9e1ed84c-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9e1ed84c-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9e1ed84c-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9e1ed84c-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/94855ef3-9915-11ee-9103-bbb8eae05561/
# dl_challenge/94855ef3-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/94855ef3-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/94855ef3-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/94855ef3-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/a2d44074-9915-11ee-9103-bbb8eae05561/
# dl_challenge/a2d44074-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/a2d44074-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/a2d44074-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/a2d44074-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8658b66c-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8658b66c-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8658b66c-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8658b66c-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8658b66c-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8eaf3ee7-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8eaf3ee7-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8eaf3ee7-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8eaf3ee7-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8eaf3ee7-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8eaf3ee5-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8eaf3ee5-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8eaf3ee5-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8eaf3ee5-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8eaf3ee5-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/911224fb-9915-11ee-9103-bbb8eae05561/
# dl_challenge/911224fb-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/911224fb-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/911224fb-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/911224fb-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/889a9fb4-9915-11ee-9103-bbb8eae05561/
# dl_challenge/889a9fb4-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/889a9fb4-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/889a9fb4-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/889a9fb4-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/95c679cd-9915-11ee-9103-bbb8eae05561/
# dl_challenge/95c679cd-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/95c679cd-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/95c679cd-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/95c679cd-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8d6c8240-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8d6c8240-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8d6c8240-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8d6c8240-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8d6c8240-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8b061a8e-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8b061a8e-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8b061a8e-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8b061a8e-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8b061a8e-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8c39418f-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8c39418f-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8c39418f-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8c39418f-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8c39418f-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8b061a89-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8b061a89-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8b061a89-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8b061a89-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8b061a89-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/983022ae-9915-11ee-9103-bbb8eae05561/
# dl_challenge/983022ae-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/983022ae-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/983022ae-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/983022ae-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/94855ef9-9915-11ee-9103-bbb8eae05561/
# dl_challenge/94855ef9-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/94855ef9-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/94855ef9-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/94855ef9-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/983022a8-9915-11ee-9103-bbb8eae05561/
# dl_challenge/983022a8-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/983022a8-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/983022a8-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/983022a8-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9950f10d-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9950f10d-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9950f10d-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9950f10d-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9950f10d-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9bccdb81-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9bccdb81-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9bccdb81-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9bccdb81-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9bccdb81-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8d6c823f-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8d6c823f-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8d6c823f-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8d6c823f-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8d6c823f-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9950f10a-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9950f10a-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9950f10a-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9950f10a-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9950f10a-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8c39418c-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8c39418c-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8c39418c-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8c39418c-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8c39418c-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8d6c823b-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8d6c823b-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8d6c823b-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8d6c823b-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8d6c823b-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/936fee3c-9915-11ee-9103-bbb8eae05561/
# dl_challenge/936fee3c-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/936fee3c-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/936fee3c-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/936fee3c-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/95c679d3-9915-11ee-9103-bbb8eae05561/
# dl_challenge/95c679d3-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/95c679d3-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/95c679d3-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/95c679d3-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/a0818ba7-9915-11ee-9103-bbb8eae05561/
# dl_challenge/a0818ba7-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/a0818ba7-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/a0818ba7-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/a0818ba7-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/a1c1d8c2-9915-11ee-9103-bbb8eae05561/
# dl_challenge/a1c1d8c2-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/a1c1d8c2-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/a1c1d8c2-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/a1c1d8c2-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9ce2867f-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9ce2867f-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9ce2867f-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9ce2867f-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9ce2867f-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/8fc581d0-9915-11ee-9103-bbb8eae05561/
# dl_challenge/8fc581d0-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/8fc581d0-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/8fc581d0-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/8fc581d0-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/9a7caa9e-9915-11ee-9103-bbb8eae05561/
# dl_challenge/9a7caa9e-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/9a7caa9e-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/9a7caa9e-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/9a7caa9e-9915-11ee-9103-bbb8eae05561/mask.npy
# dl_challenge/911224f8-9915-11ee-9103-bbb8eae05561/
# dl_challenge/911224f8-9915-11ee-9103-bbb8eae05561/rgb.jpg
# dl_challenge/911224f8-9915-11ee-9103-bbb8eae05561/pc.npy
# dl_challenge/911224f8-9915-11ee-9103-bbb8eae05561/bbox3d.npy
# dl_challenge/911224f8-9915-11ee-9103-bbb8eae05561/mask.npy

# %%
import torch
from torch.utils.data import Dataset
import cv2
import numpy as np
import albumentations as A
import os

def corners_to_7params(corners):
    """
    Converts 8 corners (shape (8,3)) into a 7-parameter representation:
      [center_x, center_y, center_z, dx, dy, dz, heading].
    For simplicity, we assume the box is axis-aligned so heading is set to 0.
    """
    center = np.mean(corners, axis=0)
    min_vals = np.min(corners, axis=0)
    max_vals = np.max(corners, axis=0)
    dims = max_vals - min_vals
    heading = 0.0
    return np.concatenate([center, dims, [heading]])

class Sereact3DDataset(Dataset):
    def __init__(self, folder_list, transform=None):
        self.folder_list = folder_list
        self.transform = transform
        self.folder_list = [
            f for f in self.folder_list
            if all(os.path.isfile(os.path.join(f, fname))
                   for fname in ['rgb.jpg', 'bbox3d.npy', 'mask.npy', 'pc.npy'])
        ]

    def __len__(self):
        return len(self.folder_list)

    def __getitem__(self, idx):
        folder_path = self.folder_list[idx]
        rgb_path   = os.path.join(folder_path, 'rgb.jpg')
        bbox_path  = os.path.join(folder_path, 'bbox3d.npy')
        mask_path  = os.path.join(folder_path, 'mask.npy')
        pc_path    = os.path.join(folder_path, 'pc.npy')

        rgb = cv2.imread(rgb_path)[:, :, ::-1]  # Convert BGR to RGB
        bbox3d_data = np.load(bbox_path)        # Could be of different shapes
        mask_data = np.load(mask_path)
        pc_data = np.load(pc_path)

        # Process bounding box data:
        # If it is 1D with 7 elements, use it directly.
        # Otherwise, if it is not of size 7 but is a multiple of 24,
        # we assume it stores boxes as 8 corners (24 numbers) and we select the first box.
        bbox3d_data = np.squeeze(bbox3d_data)
        if bbox3d_data.size == 7:
            bbox_final = bbox3d_data
        elif bbox3d_data.size % 24 == 0:
            # Assume shape is (num_boxes, 24) when reshaped
            num_boxes = bbox3d_data.size // 24
            bbox3d_data = bbox3d_data.reshape(num_boxes, 24)
            # Select the first bounding box (or choose another strategy, e.g. largest area)
            first_box = bbox3d_data[0]
            # Convert the 24-element vector (8 corners) to 7 parameters.
            corners = first_box.reshape(8, 3)
            bbox_final = corners_to_7params(corners)
        else:
            raise ValueError(f"Unexpected bounding box size: {bbox3d_data.size}")

        # Process point cloud: if shape is [3, H, W], reshape it to [H*W, 3]
        if pc_data.ndim == 3 and pc_data.shape[0] == 3:
            pc_data = np.transpose(pc_data, (1,2,0))
            pc_data = pc_data.reshape(-1, 3)

        if self.transform:
            augmented = self.transform(image=rgb)
            rgb = augmented['image']

        rgb_t = torch.from_numpy(rgb).permute(2, 0, 1).float()
        bbox3d_t = torch.from_numpy(bbox_final).float()  # Now shape (7,)
        mask_t = torch.from_numpy(mask_data).float()
        pc_t = torch.from_numpy(pc_data).float()

        return {'rgb': rgb_t, 'bbox3d': bbox3d_t, 'mask': mask_t, 'point_cloud': pc_t}

# %%
import glob
from torch.utils.data import DataLoader
import albumentations as A

def custom_collate(batch):
    collated = {}
    for key in batch[0]:
        try:
            collated[key] = torch.stack([item[key] for item in batch], dim=0)
        except RuntimeError:
            collated[key] = [item[key] for item in batch]
    return collated

# Define augmentations.
train_transform = A.Compose([
    A.Resize(224, 224),
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.2),
    A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=15, p=0.5),
])
val_transform = A.Compose([A.Resize(224, 224)])

data_dir = 'dl_challenge'
folders = sorted(glob.glob(os.path.join(data_dir, '*')))

train_folders = folders[:150]
val_folders   = folders[150:180]
test_folders  = folders[180:]

train_dataset = Sereact3DDataset(train_folders, transform=train_transform)
val_dataset = Sereact3DDataset(val_folders, transform=val_transform)
test_dataset = Sereact3DDataset(test_folders, transform=val_transform)

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, collate_fn=custom_collate)
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False, collate_fn=custom_collate)
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False, collate_fn=custom_collate)
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:58: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)

# %%
import torch.nn as nn
import torch.nn.functional as F

class YOLO3DModel(nn.Module):
    def __init__(self, grid_size=7, num_anchors=1):
        super(YOLO3DModel, self).__init__()
        self.grid_size = grid_size
        self.num_anchors = num_anchors

        # Backbone: a small CNN similar to YOLO's initial layers.
        self.features = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1),  # [B,16,224,224]
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(2, 2),  # [B,16,112,112]

            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),  # [B,32,112,112]
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(2, 2),  # [B,32,56,56]

            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),   # [B,64,56,56]
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(2, 2),  # [B,64,28,28]

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),  # [B,128,28,28]
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(2, 2),  # [B,128,14,14]

            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),  # [B,256,14,14]
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(2, 2)   # [B,256,7,7] --> matches our grid size 7x7
        )

        # Detection head: predict 7 parameters per grid cell, per anchor.
        # Here we assume only one class (or no class info needed) and no objectness score,
        # but in practice you might add these.
        self.detector = nn.Sequential(
            nn.Conv2d(256, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.1),
            nn.Conv2d(128, num_anchors * 7, kernel_size=1)  # Each grid cell predicts 7 values.
        )

    def forward(self, x):
        # x: [B, 3, 224, 224]
        features = self.features(x)  # [B,256,7,7]
        detections = self.detector(features)  # [B, num_anchors*7, 7, 7]
        B, C, H, W = detections.shape
        # Reshape to [B, H, W, num_anchors, 7]
        detections = detections.view(B, self.num_anchors, 7, H, W)
        detections = detections.permute(0, 3, 4, 1, 2).contiguous()  # [B,7,7,num_anchors,7]
        # Flatten grid cells and anchors: [B, 7*7*num_anchors, 7]
        detections = detections.view(B, -1, 7)
        return detections

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import logging
import csv

def bbox3d_loss(pred, target):
    return F.smooth_l1_loss(pred, target)

def train_model_yolo(model, train_loader, val_loader, criterion, optimizer, num_epochs=10, device='cuda', patience=3):
    model.to(device)
    train_losses = []
    val_losses = []
    best_val_loss = float('inf')
    epochs_no_improve = 0

    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=1, verbose=True)

    logging.basicConfig(filename='training.log', level=logging.INFO, format='%(asctime)s %(message)s')
    csv_filename = 'training_metrics.csv'
    with open(csv_filename, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['epoch', 'train_loss', 'val_loss'])

    for epoch in range(num_epochs):
        model.train()
        total_train_loss = 0.0
        for batch in train_loader:
            rgb = batch['rgb'].to(device)
            # For YOLO model, we assume ground truth is provided per sample as a 7-element vector.
            # In practice, you might have multiple detections per image.
            gt_bbox = batch['bbox3d'].to(device)  # shape: [B, 7] if one bbox per image.

            optimizer.zero_grad()
            pred_bbox = model(rgb)  # output shape: [B, 7*7*num_anchors, 7]
            # For simplicity, assume we only care about one predicted bbox per image
            # (e.g., use the prediction from the center cell). In practice, you'd match anchors.
            # Here we just take the first prediction for each sample.
            pred_bbox = pred_bbox[:, 0, :]  # shape: [B, 7]

            loss = criterion(pred_bbox, gt_bbox)
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()

        avg_train_loss = total_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)

        model.eval()
        total_val_loss = 0.0
        with torch.no_grad():
            for batch in val_loader:
                rgb = batch['rgb'].to(device)
                gt_bbox = batch['bbox3d'].to(device)
                pred_bbox = model(rgb)
                pred_bbox = pred_bbox[:, 0, :]
                val_loss = criterion(pred_bbox, gt_bbox)
                total_val_loss += val_loss.item()
        avg_val_loss = total_val_loss / len(val_loader)
        val_losses.append(avg_val_loss)

        scheduler.step(avg_val_loss)
        log_str = f"Epoch {epoch+1}/{num_epochs}, Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}"
        print(log_str)
        logging.info(log_str)

        with open(csv_filename, 'a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow([epoch+1, avg_train_loss, avg_val_loss])

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            print(f"No improvement for {epochs_no_improve} epochs.")
            logging.info(f"No improvement for {epochs_no_improve} epochs.")

        if epochs_no_improve >= patience:
            print("Early stopping triggered.")
            logging.info("Early stopping triggered.")
            break

    return train_losses, val_losses

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using device:", device)

model = YOLO3DModel(grid_size=7, num_anchors=1)
model.to(device)

optimizer = optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-5)
criterion = bbox3d_loss

train_losses, val_losses = train_model_yolo(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    num_epochs=10,
    device=device,
    patience=3
)
# Out:
# Using device: cuda
# Epoch 1/10, Train Loss: 0.0178, Val Loss: 0.0056
# Epoch 2/10, Train Loss: 0.0068, Val Loss: 0.0056
# No improvement for 1 epochs.
# Epoch 3/10, Train Loss: 0.0053, Val Loss: 0.0049
# Epoch 4/10, Train Loss: 0.0043, Val Loss: 0.0037
# Epoch 5/10, Train Loss: 0.0033, Val Loss: 0.0034
# Epoch 6/10, Train Loss: 0.0032, Val Loss: 0.0035
# No improvement for 1 epochs.
# Epoch 7/10, Train Loss: 0.0031, Val Loss: 0.0033
# Epoch 8/10, Train Loss: 0.0028, Val Loss: 0.0032
# Epoch 9/10, Train Loss: 0.0027, Val Loss: 0.0032
# No improvement for 1 epochs.
# Epoch 10/10, Train Loss: 0.0025, Val Loss: 0.0032
# No improvement for 2 epochs.

# %%
def project_bbox_2d_from_yolo(bbox, image_shape=(224,224), coords_normalized=True):
    # bbox: 7-element vector: [x, y, z, dx, dy, dz, heading]
    img_h, img_w = image_shape
    x, y, z, dx, dy, dz, heading = bbox
    if coords_normalized:
        x *= img_w
        y *= img_h
        dx *= img_w
        dy *= img_h
    xmin = x - dx/2
    xmax = x + dx/2
    ymin = y - dy/2
    ymax = y + dy/2
    xmin = max(0, xmin)
    ymin = max(0, ymin)
    xmax = min(img_w, xmax)
    ymax = min(img_h, ymax)
    return xmin, ymin, xmax, ymax

def visualize_2d_bbox_yolo(folder_path, pred_bbox, gt_bbox, image_shape=(224,224)):
    rgb = cv2.imread(os.path.join(folder_path, 'rgb.jpg'))[:, :, ::-1]
    transform = A.Compose([A.Resize(image_shape[0], image_shape[1])])
    rgb_aug = transform(image=rgb)['image']

    pred_box = project_bbox_2d_from_yolo(pred_bbox, image_shape=image_shape, coords_normalized=True)
    gt_box = project_bbox_2d_from_yolo(gt_bbox, image_shape=image_shape, coords_normalized=True)

    fig, ax = plt.subplots(1, 1, figsize=(6,6))
    ax.imshow(rgb_aug)
    rect_pred = plt.Rectangle((pred_box[0], pred_box[1]),
                              pred_box[2]-pred_box[0],
                              pred_box[3]-pred_box[1],
                              fill=False, edgecolor='red', linewidth=3, label='Prediction')
    rect_gt = plt.Rectangle((gt_box[0], gt_box[1]),
                              gt_box[2]-gt_box[0],
                              gt_box[3]-gt_box[1],
                              fill=False, edgecolor='green', linewidth=3, label='Ground Truth')
    ax.add_patch(rect_pred)
    ax.add_patch(rect_gt)
    ax.legend()
    ax.set_title("2D Projection of YOLO 3D BBox")
    plt.axis("off")
    plt.show()

def visualize_3d_bbox_yolo(folder_path, pred_bbox, gt_bbox):
    # For 3D visualization, we will plot the centers.
    # In a complete system, you would reconstruct the full 3D box.
    pc = np.load(os.path.join(folder_path, 'pc.npy'))
    if pc.ndim == 3 and pc.shape[0] == 3:
        pc = np.transpose(pc, (1,2,0)).reshape(-1, 3)
    if pc.shape[0] > 5000:
        idx = np.random.choice(pc.shape[0], 5000, replace=False)
        pc = pc[idx, :]

    pred_center = pred_bbox[:3]
    gt_center = gt_bbox[:3]

    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(pc[:,0], pc[:,1], pc[:,2], s=1, c='gray', alpha=0.5, label='Point Cloud')
    ax.scatter(pred_center[0], pred_center[1], pred_center[2], c='red', s=50, label='Prediction Center')
    ax.scatter(gt_center[0], gt_center[1], gt_center[2], c='green', s=50, label='GT Center')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.legend()
    ax.set_title("3D Visualization: BBox Centers")
    plt.show()

# Evaluate and visualize:
model.eval()
with torch.no_grad():
    for idx, batch in enumerate(test_loader):
        rgb = batch['rgb'].to(device)
        gt_bbox = batch['bbox3d'].to(device)
        pred_bbox = model(rgb)  # YOLO model outputs [B, 7]

        pred_bbox_sample = pred_bbox[0].cpu().numpy()
        gt_bbox_sample = gt_bbox[0].cpu().numpy()
        sample_folder = test_folders[idx]

        print("Predicted 3D BBox:", pred_bbox_sample)
        print("Ground Truth 3D BBox:", gt_bbox_sample)

        visualize_2d_bbox_yolo(sample_folder, pred_bbox_sample, gt_bbox_sample, image_shape=(224,224))
        visualize_3d_bbox_yolo(sample_folder, pred_bbox_sample, gt_bbox_sample)
        break
# Out:
# Predicted 3D BBox: [[-3.53548825e-02 -3.38993827e-03  1.12962115e+00  1.85610473e-01
#    1.85809016e-01  1.00645833e-01 -4.52358276e-03]
#  [-1.08058006e-01 -2.21356954e-02  6.39100254e-01  2.59341337e-02
#    1.15205914e-01  2.95251548e-01  9.49093625e-02]
#  [-1.27711147e-02 -3.92076336e-02  7.40729988e-01  2.64516830e-01
#    2.34324008e-01  1.81283176e-01 -5.05844131e-03]
#  [-1.99563801e-01 -1.04054678e-02  5.45952499e-01  7.36568868e-02
#    1.93361342e-01  1.57665759e-01 -2.62960717e-02]
#  [-2.31507003e-01  1.55084226e-02  4.63510603e-01  2.00940557e-02
#    2.27932632e-01  1.80549338e-01  5.50751314e-02]
#  [-1.35064870e-01 -8.11409764e-03  7.68112242e-01  1.59620136e-01
#    1.80514246e-01  1.31509155e-01 -9.16884094e-02]
#  [-2.24104375e-01 -1.46498919e-01  5.54047227e-01 -2.70931840e-01
#    1.82016611e-01  1.81429237e-01 -3.20196673e-02]
#  [ 1.16348714e-02 -4.96539399e-02  8.24663162e-01  1.75475910e-01
#    1.70860216e-01  9.64743122e-02 -2.71716639e-02]
#  [ 2.85898805e-01 -7.74158314e-02 -1.12013392e-01 -1.67348847e-01
#   -2.44419932e-01  2.72548944e-03 -2.08713338e-02]
#  [ 9.07155424e-02 -1.15517423e-01  3.53195518e-01  1.43510215e-02
#   -4.19515744e-02  8.82725343e-02 -1.20659292e-01]
#  [-1.71122536e-01 -4.10595924e-01 -2.59250253e-01 -5.65535247e-01
#    1.99184388e-01  1.20666027e-01 -2.99120963e-01]
#  [-1.20137155e-01 -1.48317516e-01 -1.92709953e-01 -9.25977081e-02
#    2.99935251e-01 -3.64215165e-01  3.92313719e-01]
#  [ 6.58475012e-02  5.10297604e-02  2.13112712e-01 -2.60176137e-02
#   -1.24687798e-01 -9.83297825e-04 -3.28078642e-02]
#  [ 1.12658948e-01 -7.59363174e-02 -1.88694924e-01 -5.72658300e-01
#   -1.46422282e-01  1.97800308e-01  1.06319539e-01]
#  [ 2.99637988e-02 -1.55207235e-04  8.02254736e-01  1.40202045e-01
#    1.32737696e-01  6.60637617e-02 -3.34733054e-02]
#  [ 1.00387499e-01  7.61402249e-02 -1.13550566e-01 -6.10289350e-03
#    7.06546940e-03  2.35121399e-01  2.41097510e-01]
#  [ 1.67497098e-01 -9.36657377e-03  2.25146353e-01  1.95597187e-01
#   -5.32818288e-02  1.17597476e-01 -1.92510128e-01]
#  [-6.56830445e-02 -7.16963470e-01 -5.73754549e-01 -2.68293351e-01
#    2.72107366e-02  3.76824439e-01 -1.39767855e-01]
#  [ 3.16942543e-01 -4.81706679e-01 -4.23173279e-01 -5.04503965e-01
#    3.79683822e-01  1.23964787e-01  7.97829702e-02]
#  [ 2.52985120e-01  8.87393393e-03 -7.58936182e-02 -1.97632872e-02
#    1.81927949e-01  3.12301487e-01 -9.48469639e-02]
#  [ 2.52107620e-01 -3.05585831e-01 -3.63190979e-01 -5.43561459e-01
#   -5.58363087e-03  5.32456100e-01 -1.03576653e-01]
#  [-5.23985177e-02  1.98662803e-02  8.72308671e-01  1.66342616e-01
#    2.08831906e-01  1.04293384e-01 -3.12771499e-02]
#  [ 7.66141564e-02  6.04522740e-03 -8.93129483e-02 -1.48719177e-01
#    2.78430134e-01  3.24560493e-01  1.60619676e-01]
#  [ 3.66321266e-01 -2.27267504e-01  1.34352595e-03 -4.86997329e-02
#    1.42998531e-01  2.19742209e-01  5.11896238e-03]
#  [ 4.87279594e-01 -3.04275304e-01 -5.15928447e-01 -3.57395977e-01
#   -5.35947978e-02  2.42565900e-01 -2.04994455e-02]
#  [ 2.15991378e-01 -1.19015291e-01 -8.13476741e-01 -4.09893930e-01
#    3.48073393e-01  7.44412839e-01 -7.01248199e-02]
#  [ 1.66426793e-01 -3.61943424e-01  1.65192820e-02 -8.27451050e-02
#   -2.10041683e-02  4.31397051e-01 -8.63717943e-02]
#  [ 3.17635000e-01 -7.78180063e-02 -2.48542070e-01 -4.75296557e-01
#    2.68534757e-03  2.28940606e-01 -4.72616926e-02]
#  [-3.85352522e-02 -2.96351630e-02  8.88169944e-01  1.79361895e-01
#    1.51386291e-01  1.13855802e-01 -7.77404681e-02]
#  [-4.68647778e-02  5.65551780e-02  1.32992119e-03 -6.83389530e-02
#    1.31758243e-01  3.51167887e-01  1.16354011e-01]
#  [ 2.91816741e-01 -1.14650629e-01  9.98161510e-02 -2.00006932e-01
#    1.97989702e-01  1.19659081e-01  1.68975353e-01]
#  [ 4.16754305e-01 -2.09867835e-01 -1.03194289e-01 -1.21074766e-01
#   -3.04623265e-02  2.05002278e-01  6.58794492e-02]
#  [ 1.19612962e-02  4.29629795e-02 -7.15778694e-02 -1.47849470e-01
#    3.64095271e-01  3.75785381e-01 -2.02910453e-02]
#  [ 2.88405120e-02  4.92570214e-02 -3.17051634e-02 -2.96723992e-02
#    1.82473600e-01  3.13194394e-01 -5.20141572e-02]
#  [ 3.35961699e-01 -1.81723669e-01 -7.03918934e-03 -2.01714128e-01
#   -1.58930477e-02  3.06320518e-01  4.73241135e-02]
#  [-7.37475604e-03 -6.62397370e-02  9.18636799e-01  1.10307947e-01
#    1.50405064e-01  4.58751321e-02 -1.30986497e-02]
#  [ 7.27766901e-02 -3.72229777e-02  2.13192523e-01 -4.78846878e-02
#   -6.11120239e-02  1.91964537e-01  6.96208626e-02]
#  [ 4.60924357e-02  1.97240468e-02  5.43285966e-01  2.13158838e-02
#    7.24734440e-02  5.87943345e-02  1.12248950e-01]
#  [ 5.06044328e-02 -5.22593148e-02  4.74823296e-01  6.38874620e-03
#    6.91308528e-02  8.80677775e-02  1.38007522e-01]
#  [-9.44774300e-02 -1.04532100e-01  4.10391808e-01  2.98013277e-02
#    5.56945801e-02  1.33132949e-01  5.76284602e-02]
#  [ 5.78536987e-02  1.69162136e-02  1.98814750e-01  8.59910548e-02
#    2.62679886e-02  1.21145949e-01 -9.55716074e-02]
#  [ 6.86982274e-03 -8.92327130e-02  1.56063259e-01 -1.81158498e-01
#   -6.37247041e-02  2.16699660e-01  4.87635657e-02]
#  [ 4.25376520e-02  3.56760733e-02  7.20578134e-01  1.12157315e-01
#    1.56870782e-01  1.24652781e-01 -7.50007778e-02]
#  [-7.73141980e-02  1.65160239e-01  1.55974522e-01  1.28451020e-01
#    1.51485175e-01  3.30474168e-01 -2.48109937e-01]
#  [-1.12473853e-02  1.24622881e-01  3.20841014e-01 -3.32807973e-02
#    1.20943278e-01  2.34267235e-01 -1.94617182e-01]
#  [ 2.17994601e-02  6.50739521e-02  3.33263546e-01 -3.76010500e-02
#    1.32264867e-01  2.45459616e-01 -2.29142278e-01]
#  [ 7.87180513e-02  7.60416538e-02  2.84485310e-01 -1.19394869e-01
#    1.09567821e-01  1.92501619e-01 -1.26235098e-01]
#  [ 9.59953517e-02  7.68536329e-02  5.70475236e-02 -6.46392033e-02
#    7.70812035e-02  2.71857977e-01 -2.05938011e-01]
#  [ 2.30535090e-01  1.92498099e-02  1.49516866e-01 -5.70381619e-02
#    2.38963384e-02  2.38971740e-01 -2.21977949e-01]]
# Ground Truth 3D BBox: [ 0.1006356  -0.05980101  1.147215    0.25428092  0.2518314   0.19167674
#   0.        ]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-4d3ac9036256> in <cell line: 0>()
#      83         print("Ground Truth 3D BBox:", gt_bbox_sample)
#      84
# ---> 85         visualize_2d_bbox_yolo(sample_folder, pred_bbox_sample, gt_bbox_sample, image_shape=(224,224))
#      86         visualize_3d_bbox_yolo(sample_folder, pred_bbox_sample, gt_bbox_sample)
#      87         break
#
# <ipython-input-12-4d3ac9036256> in visualize_2d_bbox_yolo(folder_path, pred_bbox, gt_bbox, image_shape)
#      23     rgb_aug = transform(image=rgb)['image']
#      24
# ---> 25     pred_box = project_bbox_2d_from_yolo(pred_bbox, image_shape=image_shape, coords_normalized=True)
#      26     gt_box = project_bbox_2d_from_yolo(gt_bbox, image_shape=image_shape, coords_normalized=True)
#      27
#
# <ipython-input-12-4d3ac9036256> in project_bbox_2d_from_yolo(bbox, image_shape, coords_normalized)
#       2     # bbox: 7-element vector: [x, y, z, dx, dy, dz, heading]
#       3     img_h, img_w = image_shape
# ----> 4     x, y, z, dx, dy, dz, heading = bbox
#       5     if coords_normalized:
#       6         x *= img_w
#
# ValueError: too many values to unpack (expected 7)

# %%
# ONNX Export: Export the model to ONNX format for deployment.
dummy_input = torch.randn(1, 3, 224, 224).to(device)
torch.onnx.export(model, dummy_input, "yolo3d_model.onnx", opset_version=11)

# Git Logging: Push key files to your GitHub repository.
# !git config --global user.email "sp.tangadpalliwar@stud.fh-sm.de"
# !git config --global user.name "https://github.com/shubhamt2897"
# !git init
# !git branch -M main
# !echo "dl_challenge/" >> .gitignore
# !echo "dl_challenge.tar.xz" >> .gitignore
# !echo "sample_data/" >> .gitignore
# !git add DL_Bounding_Box.ipynb training_metrics.csv training.log yolo3d_model.onnx
# !git commit -m "Final commit: YOLO3D pipeline and logs"
# !git remote add origin https://github.com/shubhamt2897/DL_BB_YOLO.git
# !git push -u origin main
